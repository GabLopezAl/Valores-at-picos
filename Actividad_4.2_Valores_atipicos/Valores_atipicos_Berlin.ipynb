# %% [markdown]
# **Importar librerías**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mt
import seaborn as sns

# %%
# Leer archivo csv
df = pd.read_csv("Berlin.csv", encoding = "MacRoman")
df
# Out:
#        Unnamed: 0            id last_scraped  \
# 0               0  5.704900e+04   18/09/2024
# 1               1  5.878000e+04   18/09/2024
# 2               2  6.261300e+04   18/09/2024
# 3               3  6.401400e+04   18/09/2024
# 4               4  6.424500e+04   18/09/2024
# ...           ...           ...          ...
# 11522       11522  1.020000e+18   18/09/2024
# 11523       11523  1.020000e+18   18/09/2024
# 11524       11524  1.020000e+18   18/09/2024
# 11525       11525  1.020000e+18   18/09/2024
# 11526       11526  1.020000e+18   18/09/2024
#
#                                                     name  \
# 0                      130 sqm with a view on Mauer Park
# 1                      light quiet beautiful 4 room flat
# 2                    Super Apartment in Berlin/Kreuzberg
# 3      Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4      Room w/ balcony and private bathroom in nice area
# ...                                                  ...
# 11522                                          Studio 40
# 11523                                     Garden Loft 80
# 11524                           Extended Garden Loft 107
# 11525                                    Garden Loft 115
# 11526                           Extended Garden Loft 139
#
#                                              description  \
# 0      An apartment of 130 sqm right in the heart of ...
# 1      We offer our 4 room apartment in Prenzlauer Be...
# 2      Our fantastic typical Berlin-style apartment i...
# 3      I am renting out my spacious, bright rooftop a...
# 4      I¬¨¬•m offering a guest room with balcony in m...
# ...                                                  ...
# 11522  This modern flat is located in the new Carlott...
# 11523  This modern apartment is located in the new Ca...
# 11524  This modern flat is located in the new Carlott...
# 11525  This modern apartment is located in the new Ca...
# 11526  This modern flat is located in the new Carlott...
#
#                                    neighborhood_overview  \
# 0      Prenzlauer Berg is no doubt one of the most my...
# 1      Prenzlauer Berg is no doubt one of the most my...
# 2      Prenzlauer Berg is no doubt one of the most my...
# 3      Kastanienalle, Oderberger Strasse, Hackescher ...
# 4      The neighborhood "Prenzlauer Berg" is centrall...
# ...                                                  ...
# 11522  Charlottenburg in the western part of Berlin, ...
# 11523  Charlottenburg in the western part of Berlin, ...
# 11524  Charlottenburg in the western part of Berlin, ...
# 11525  Charlottenburg in the western part of Berlin, ...
# 11526  Charlottenburg in the western part of Berlin, ...
#
#                                              picture_url            host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...               Marine
# 1      https://a0.muscache.com/pictures/caa048ba-e297...                Katja
# 2      https://a0.muscache.com/pictures/176e2964-5ead...                Guidi
# 3      https://a0.muscache.com/pictures/1135114/9db3c...              Stephan
# 4      https://a0.muscache.com/pictures/miso/Hosting-...            Christian
# ...                                                  ...                  ...
# 11522  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11523  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11524  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11525  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11526  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
#
#        host_since                                         host_about  ...  \
# 0      14/11/2009  I'm french but I have been living in Berlin si...  ...
# 1      08/11/2010           Designer who likes discovering the world  ...
# 2      08/09/2010  Hi , I am Elena and I am looking forward to ho...  ...
# 3      08/12/2010  Ich mag sch‚àö‚àÇne Dinge und Design. Wenn es ...  ...
# 4      07/12/2010  Christian from Berlin\n\nHi, I¬¨¬•m a 52 years...  ...
# ...           ...                                                ...  ...
# 11522  24/10/2023  "If you think you can do a thing or think you ...  ...
# 11523  24/10/2023  "If you think you can do a thing or think you ...  ...
# 11524  24/10/2023  "If you think you can do a thing or think you ...  ...
# 11525  24/10/2023  "If you think you can do a thing or think you ...  ...
# 11526  24/10/2023  "If you think you can do a thing or think you ...  ...
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     4.93                    4.95                       4.90
# 1                     4.84                    4.88                       4.79
# 2                     4.70                    4.68                       4.65
# 3                     4.75                    4.63                       4.50
# 4                     4.95                    4.95                       4.92
# ...                    ...                     ...                        ...
# 11522                 5.00                    5.00                       4.91
# 11523                 4.83                    5.00                       5.00
# 11524                 5.00                    5.00                       5.00
# 11525                 4.67                    4.67                       5.00
# 11526                 4.97                    4.97                       5.00
#
#       review_scores_checkin  review_scores_communication  \
# 0                      4.97                         4.94
# 1                      4.81                         4.91
# 2                      4.82                         4.82
# 3                      4.94                         4.63
# 4                      4.95                         4.92
# ...                     ...                          ...
# 11522                  4.82                         5.00
# 11523                  4.83                         5.00
# 11524                  5.00                         5.00
# 11525                  5.00                         5.00
# 11526                  4.94                         4.97
#
#        review_scores_location review_scores_value  \
# 0                        4.82                4.76
# 1                        4.87                4.73
# 2                        4.94                4.47
# 3                        4.88                4.40
# 4                        4.84                4.77
# ...                       ...                 ...
# 11522                    5.00                4.45
# 11523                    4.83                4.67
# 11524                    4.83                4.50
# 11525                    4.33                4.33
# 11526                    4.85                4.85
#
#                                                  license instant_bookable  \
# 0                                      03/Z/RA/003544-18                f
# 1                                      03/Z/RA/007133-22                f
# 2                                      02/Z/AZ/011099-19                f
# 3                                      01/Z/RA/016060-23                f
# 4                                      03/Z/AZ/006799-21                f
# ...                                                  ...              ...
# 11522  Legal entity name and Legal form: Godebo GmbH ...                t
# 11523  Legal entity name and Legal form: Godebo GmbH ...                t
# 11524  Legal entity name and Legal form: Godebo GmbH ...                t
# 11525  Legal entity name and Legal form: Godebo GmbH ...                t
# 11526  Legal entity name and Legal form: Godebo GmbH ...                t
#
#       reviews_per_month
# 0                  0.80
# 1                  0.43
# 2                  0.20
# 3                  0.10
# 4                  0.73
# ...                 ...
# 11522              1.21
# 11523              0.65
# 11524              1.84
# 11525              0.94
# 11526              3.69
#
# [11527 rows x 51 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# id                             0
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms                      0
# bathrooms_text                 0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# calendar_updated               0
# has_availability               0
# availability_30                0
# availability_60                0
# availability_365               0
# calendar_last_scraped          0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# last_review                    0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# license                        0
# instant_bookable               0
# reviews_per_month              0
# dtype: int64

# %%
# Eliminar columna "Unnamed: 0"
df2 = df.drop(['Unnamed: 0'], axis = 1)
df2
# Out:
#                  id last_scraped  \
# 0      5.704900e+04   18/09/2024
# 1      5.878000e+04   18/09/2024
# 2      6.261300e+04   18/09/2024
# 3      6.401400e+04   18/09/2024
# 4      6.424500e+04   18/09/2024
# ...             ...          ...
# 11522  1.020000e+18   18/09/2024
# 11523  1.020000e+18   18/09/2024
# 11524  1.020000e+18   18/09/2024
# 11525  1.020000e+18   18/09/2024
# 11526  1.020000e+18   18/09/2024
#
#                                                     name  \
# 0                      130 sqm with a view on Mauer Park
# 1                      light quiet beautiful 4 room flat
# 2                    Super Apartment in Berlin/Kreuzberg
# 3      Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4      Room w/ balcony and private bathroom in nice area
# ...                                                  ...
# 11522                                          Studio 40
# 11523                                     Garden Loft 80
# 11524                           Extended Garden Loft 107
# 11525                                    Garden Loft 115
# 11526                           Extended Garden Loft 139
#
#                                              description  \
# 0      An apartment of 130 sqm right in the heart of ...
# 1      We offer our 4 room apartment in Prenzlauer Be...
# 2      Our fantastic typical Berlin-style apartment i...
# 3      I am renting out my spacious, bright rooftop a...
# 4      I¬¨¬•m offering a guest room with balcony in m...
# ...                                                  ...
# 11522  This modern flat is located in the new Carlott...
# 11523  This modern apartment is located in the new Ca...
# 11524  This modern flat is located in the new Carlott...
# 11525  This modern apartment is located in the new Ca...
# 11526  This modern flat is located in the new Carlott...
#
#                                    neighborhood_overview  \
# 0      Prenzlauer Berg is no doubt one of the most my...
# 1      Prenzlauer Berg is no doubt one of the most my...
# 2      Prenzlauer Berg is no doubt one of the most my...
# 3      Kastanienalle, Oderberger Strasse, Hackescher ...
# 4      The neighborhood "Prenzlauer Berg" is centrall...
# ...                                                  ...
# 11522  Charlottenburg in the western part of Berlin, ...
# 11523  Charlottenburg in the western part of Berlin, ...
# 11524  Charlottenburg in the western part of Berlin, ...
# 11525  Charlottenburg in the western part of Berlin, ...
# 11526  Charlottenburg in the western part of Berlin, ...
#
#                                              picture_url            host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...               Marine
# 1      https://a0.muscache.com/pictures/caa048ba-e297...                Katja
# 2      https://a0.muscache.com/pictures/176e2964-5ead...                Guidi
# 3      https://a0.muscache.com/pictures/1135114/9db3c...              Stephan
# 4      https://a0.muscache.com/pictures/miso/Hosting-...            Christian
# ...                                                  ...                  ...
# 11522  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11523  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11524  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11525  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11526  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
#
#        host_since                                         host_about  \
# 0      14/11/2009  I'm french but I have been living in Berlin si...
# 1      08/11/2010           Designer who likes discovering the world
# 2      08/09/2010  Hi , I am Elena and I am looking forward to ho...
# 3      08/12/2010  Ich mag sch‚àö‚àÇne Dinge und Design. Wenn es ...
# 4      07/12/2010  Christian from Berlin\n\nHi, I¬¨¬•m a 52 years...
# ...           ...                                                ...
# 11522  24/10/2023  "If you think you can do a thing or think you ...
# 11523  24/10/2023  "If you think you can do a thing or think you ...
# 11524  24/10/2023  "If you think you can do a thing or think you ...
# 11525  24/10/2023  "If you think you can do a thing or think you ...
# 11526  24/10/2023  "If you think you can do a thing or think you ...
#
#        host_response_time  ...  review_scores_rating  review_scores_accuracy  \
# 0          within an hour  ...                  4.93                    4.95
# 1      within a few hours  ...                  4.84                    4.88
# 2      within a few hours  ...                  4.70                    4.68
# 3            within a day  ...                  4.75                    4.63
# 4      within a few hours  ...                  4.95                    4.95
# ...                   ...  ...                   ...                     ...
# 11522      within an hour  ...                  5.00                    5.00
# 11523      within an hour  ...                  4.83                    5.00
# 11524      within an hour  ...                  5.00                    5.00
# 11525      within an hour  ...                  4.67                    4.67
# 11526      within an hour  ...                  4.97                    4.97
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          4.90                   4.97
# 1                          4.79                   4.81
# 2                          4.65                   4.82
# 3                          4.50                   4.94
# 4                          4.92                   4.95
# ...                         ...                    ...
# 11522                      4.91                   4.82
# 11523                      5.00                   4.83
# 11524                      5.00                   5.00
# 11525                      5.00                   5.00
# 11526                      5.00                   4.94
#
#        review_scores_communication review_scores_location review_scores_value  \
# 0                             4.94                   4.82                4.76
# 1                             4.91                   4.87                4.73
# 2                             4.82                   4.94                4.47
# 3                             4.63                   4.88                4.40
# 4                             4.92                   4.84                4.77
# ...                            ...                    ...                 ...
# 11522                         5.00                   5.00                4.45
# 11523                         5.00                   4.83                4.67
# 11524                         5.00                   4.83                4.50
# 11525                         5.00                   4.33                4.33
# 11526                         4.97                   4.85                4.85
#
#                                                  license instant_bookable  \
# 0                                      03/Z/RA/003544-18                f
# 1                                      03/Z/RA/007133-22                f
# 2                                      02/Z/AZ/011099-19                f
# 3                                      01/Z/RA/016060-23                f
# 4                                      03/Z/AZ/006799-21                f
# ...                                                  ...              ...
# 11522  Legal entity name and Legal form: Godebo GmbH ...                t
# 11523  Legal entity name and Legal form: Godebo GmbH ...                t
# 11524  Legal entity name and Legal form: Godebo GmbH ...                t
# 11525  Legal entity name and Legal form: Godebo GmbH ...                t
# 11526  Legal entity name and Legal form: Godebo GmbH ...                t
#
#       reviews_per_month
# 0                  0.80
# 1                  0.43
# 2                  0.20
# 3                  0.10
# 4                  0.73
# ...                 ...
# 11522              1.21
# 11523              0.65
# 11524              1.84
# 11525              0.94
# 11526              3.69
#
# [11527 rows x 50 columns]

# %%
# Crear dos dataframes para procesar los outliers
cualitativas = df.iloc[:, [2,3,4,5,6,7,8,9,10,13,16,17,18,19,20,21,24,27,31,32,36,40,48,49]] 
cuantitativas = df.iloc[:, [1,11,12,14,15,22,23,25,26,28,29,30,33,34,35,37,38,39,41,42,43,44,45,46,47,50]]

# %%
# Mostrar variables cualitativas
cualitativas
# Out:
#       last_scraped                                               name  \
# 0       18/09/2024                  130 sqm with a view on Mauer Park
# 1       18/09/2024                  light quiet beautiful 4 room flat
# 2       18/09/2024                Super Apartment in Berlin/Kreuzberg
# 3       18/09/2024  Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4       18/09/2024  Room w/ balcony and private bathroom in nice area
# ...            ...                                                ...
# 11522   18/09/2024                                          Studio 40
# 11523   18/09/2024                                     Garden Loft 80
# 11524   18/09/2024                           Extended Garden Loft 107
# 11525   18/09/2024                                    Garden Loft 115
# 11526   18/09/2024                           Extended Garden Loft 139
#
#                                              description  \
# 0      An apartment of 130 sqm right in the heart of ...
# 1      We offer our 4 room apartment in Prenzlauer Be...
# 2      Our fantastic typical Berlin-style apartment i...
# 3      I am renting out my spacious, bright rooftop a...
# 4      I¬¨¬•m offering a guest room with balcony in m...
# ...                                                  ...
# 11522  This modern flat is located in the new Carlott...
# 11523  This modern apartment is located in the new Ca...
# 11524  This modern flat is located in the new Carlott...
# 11525  This modern apartment is located in the new Ca...
# 11526  This modern flat is located in the new Carlott...
#
#                                    neighborhood_overview  \
# 0      Prenzlauer Berg is no doubt one of the most my...
# 1      Prenzlauer Berg is no doubt one of the most my...
# 2      Prenzlauer Berg is no doubt one of the most my...
# 3      Kastanienalle, Oderberger Strasse, Hackescher ...
# 4      The neighborhood "Prenzlauer Berg" is centrall...
# ...                                                  ...
# 11522  Charlottenburg in the western part of Berlin, ...
# 11523  Charlottenburg in the western part of Berlin, ...
# 11524  Charlottenburg in the western part of Berlin, ...
# 11525  Charlottenburg in the western part of Berlin, ...
# 11526  Charlottenburg in the western part of Berlin, ...
#
#                                              picture_url            host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...               Marine
# 1      https://a0.muscache.com/pictures/caa048ba-e297...                Katja
# 2      https://a0.muscache.com/pictures/176e2964-5ead...                Guidi
# 3      https://a0.muscache.com/pictures/1135114/9db3c...              Stephan
# 4      https://a0.muscache.com/pictures/miso/Hosting-...            Christian
# ...                                                  ...                  ...
# 11522  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11523  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11524  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11525  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11526  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
#
#        host_since                                         host_about  \
# 0      14/11/2009  I'm french but I have been living in Berlin si...
# 1      08/11/2010           Designer who likes discovering the world
# 2      08/09/2010  Hi , I am Elena and I am looking forward to ho...
# 3      08/12/2010  Ich mag sch‚àö‚àÇne Dinge und Design. Wenn es ...
# 4      07/12/2010  Christian from Berlin\n\nHi, I¬¨¬•m a 52 years...
# ...           ...                                                ...
# 11522  24/10/2023  "If you think you can do a thing or think you ...
# 11523  24/10/2023  "If you think you can do a thing or think you ...
# 11524  24/10/2023  "If you think you can do a thing or think you ...
# 11525  24/10/2023  "If you think you can do a thing or think you ...
# 11526  24/10/2023  "If you think you can do a thing or think you ...
#
#        host_response_time host_is_superhost  ...                property_type  \
# 0          within an hour                 t  ...           Entire rental unit
# 1      within a few hours                 t  ...           Entire rental unit
# 2      within a few hours                 f  ...           Entire rental unit
# 3            within a day                 f  ...           Entire rental unit
# 4      within a few hours                 t  ...  Private room in rental unit
# ...                   ...               ...  ...                          ...
# 11522      within an hour                 t  ...                 Entire condo
# 11523      within an hour                 t  ...                 Entire condo
# 11524      within an hour                 t  ...                 Entire condo
# 11525      within an hour                 t  ...                 Entire condo
# 11526      within an hour                 t  ...                 Entire condo
#
#              room_type bathrooms_text  \
# 0      Entire home/apt        2 baths
# 1      Entire home/apt      1.5 baths
# 2      Entire home/apt         1 bath
# 3      Entire home/apt        2 baths
# 4         Private room      1.5 baths
# ...                ...            ...
# 11522  Entire home/apt         1 bath
# 11523  Entire home/apt         1 bath
# 11524  Entire home/apt        2 baths
# 11525  Entire home/apt         1 bath
# 11526  Entire home/apt        2 baths
#
#                                                amenities calendar_updated  \
# 0      ["Baking sheet", "Dryer", "Dedicated workspace...       20/05/2019
# 1      ["Patio or balcony", "Bed linens", "Oven", "Re...       20/05/2019
# 2      ["Refrigerator", "Dishes and silverware", "Was...       20/05/2019
# 3      ["Baking sheet", "Dining table", "Body soap", ...       20/05/2019
# 4      ["Baking sheet", "Dining table", "Dedicated wo...       20/05/2019
# ...                                                  ...              ...
# 11522  ["Baking sheet", "Dining table", "Crib", "Dedi...       20/05/2019
# 11523  ["Baking sheet", "Dining table", "Crib", "Fram...       20/05/2019
# 11524  ["Baking sheet", "Dining table", "Crib", "Dedi...       20/05/2019
# 11525  ["Baking sheet", "Dining table", "Crib", "Dedi...       20/05/2019
# 11526  ["Baking sheet", "Dining table", "Crib", "Dedi...       20/05/2019
#
#       has_availability calendar_last_scraped last_review  \
# 0                    t            18/09/2024  04/08/2024
# 1                    t            18/09/2024  19/08/2024
# 2                    t            18/09/2024  02/08/2024
# 3                    t            18/09/2024  29/07/2023
# 4                    t            18/09/2024  15/09/2024
# ...                ...                   ...         ...
# 11522                t            18/09/2024  28/08/2024
# 11523                t            18/09/2024  29/07/2024
# 11524                t            18/09/2024  19/08/2024
# 11525                t            18/09/2024  08/07/2024
# 11526                t            18/09/2024  18/09/2024
#
#                                                  license instant_bookable
# 0                                      03/Z/RA/003544-18                f
# 1                                      03/Z/RA/007133-22                f
# 2                                      02/Z/AZ/011099-19                f
# 3                                      01/Z/RA/016060-23                f
# 4                                      03/Z/AZ/006799-21                f
# ...                                                  ...              ...
# 11522  Legal entity name and Legal form: Godebo GmbH ...                t
# 11523  Legal entity name and Legal form: Godebo GmbH ...                t
# 11524  Legal entity name and Legal form: Godebo GmbH ...                t
# 11525  Legal entity name and Legal form: Godebo GmbH ...                t
# 11526  Legal entity name and Legal form: Godebo GmbH ...                t
#
# [11527 rows x 24 columns]

# %%
# Mostrar variables cuantitativas
cuantitativas
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      5.704900e+04                 1.0                  0.80
# 1      5.878000e+04                 1.0                  0.77
# 2      6.261300e+04                 1.0                  0.54
# 3      6.401400e+04                 0.5                  0.00
# 4      6.424500e+04                 1.0                  0.87
# ...             ...                 ...                   ...
# 11522  1.020000e+18                 1.0                  0.98
# 11523  1.020000e+18                 1.0                  0.98
# 11524  1.020000e+18                 1.0                  0.98
# 11525  1.020000e+18                 1.0                  0.98
# 11526  1.020000e+18                 1.0                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      3.0                          3             4
# 1                      4.0                          6             4
# 2                      1.0                          2             2
# 3                      1.0                          1             4
# 4                      1.0                          2             2
# ...                    ...                        ...           ...
# 11522                  9.0                          9             2
# 11523                  9.0                          9             2
# 11524                  9.0                          9             4
# 11525                  9.0                          9             2
# 11526                  9.0                          9             4
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            2.0         2     3    290  ...                     15
# 1            1.5         3     3    240  ...                      7
# 2            1.0         0     1    100  ...                      4
# 3            2.0         2     2    186  ...                      0
# 4            1.5         1     1     78  ...                     22
# ...          ...       ...   ...    ...  ...                    ...
# 11522        1.0         1     1    275  ...                     11
# 11523        1.0         1     1    361  ...                      6
# 11524        2.0         1     1    516  ...                      6
# 11525        1.0         1     1    384  ...                      3
# 11526        2.0         2     2    595  ...                     33
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                           0                  4.93                    4.95
# 1                           1                  4.84                    4.88
# 2                           0                  4.70                    4.68
# 3                           0                  4.75                    4.63
# 4                           3                  4.95                    4.95
# ...                       ...                   ...                     ...
# 11522                       2                  5.00                    5.00
# 11523                       0                  4.83                    5.00
# 11524                       1                  5.00                    5.00
# 11525                       0                  4.67                    4.67
# 11526                       4                  4.97                    4.97
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.90                   4.97
# 1                           4.79                   4.81
# 2                           4.65                   4.82
# 3                           4.50                   4.94
# 4                           4.92                   4.95
# ...                          ...                    ...
# 11522                       4.91                   4.82
# 11523                       5.00                   4.83
# 11524                       5.00                   5.00
# 11525                       5.00                   5.00
# 11526                       5.00                   4.94
#
#        review_scores_communication  review_scores_location  \
# 0                             4.94                    4.82
# 1                             4.91                    4.87
# 2                             4.82                    4.94
# 3                             4.63                    4.88
# 4                             4.92                    4.84
# ...                            ...                     ...
# 11522                         5.00                    5.00
# 11523                         5.00                    4.83
# 11524                         5.00                    4.83
# 11525                         5.00                    4.33
# 11526                         4.97                    4.85
#
#        review_scores_value  reviews_per_month
# 0                     4.76               0.80
# 1                     4.73               0.43
# 2                     4.47               0.20
# 3                     4.40               0.10
# 4                     4.77               0.73
# ...                    ...                ...
# 11522                 4.45               1.21
# 11523                 4.67               0.65
# 11524                 4.50               1.84
# 11525                 4.33               0.94
# 11526                 4.85               3.69
#
# [11527 rows x 26 columns]

# %%
fig = mt.figure(figsize = (15,8))
cuantitativas.plot(kind = 'box', vert = False)
mt.title("Valores Atípicos del dataframe")
mt.show() #Dibujamos el diagrama

# %% [markdown]
# **Procedimiento "Desvicación estandar" para eliminar valores atípicos del dataframe**

# %%
# Desviacion estándar: Calcular los valores extremos de cada columna
y = cuantitativas
limSup = y.mean() + 3 * y.std()
limInf = y.mean() - 3 * y.std()
print("Limite inferior: ", limInf)
print("Limite superior: ", limSup)
# Out:
# Limite inferior:  id                            -8.765432e+17
# host_response_rate             2.802529e-01
# host_acceptance_rate          -8.524889e-02
# host_listings_count           -2.404026e+02
# host_total_listings_count     -2.658685e+02
# accommodates                  -2.599122e+00
# bathrooms                      1.455868e-01
# bedrooms                      -1.019336e+00
# beds                          -1.668475e+00
# price                         -7.371401e+02
# minimum_nights                -1.261050e+02
# maximum_nights                -8.732315e+02
# availability_30               -2.155400e+01
# availability_60               -4.582217e+01
# availability_365              -2.833469e+02
# number_of_reviews             -2.463886e+02
# number_of_reviews_ltm         -5.527333e+01
# number_of_reviews_l30d        -5.275103e+00
# review_scores_rating           3.907334e+00
# review_scores_accuracy         3.963653e+00
# review_scores_cleanliness      3.651765e+00
# review_scores_checkin          4.004508e+00
# review_scores_communication    3.934693e+00
# review_scores_location         3.916728e+00
# review_scores_value            3.650097e+00
# reviews_per_month             -4.072360e+00
# dtype: float64
# Limite superior:  id                             1.320363e+18
# host_response_rate             1.566741e+00
# host_acceptance_rate           1.684930e+00
# host_listings_count            2.749721e+02
# host_total_listings_count      3.047539e+02
# accommodates                   8.478536e+00
# bathrooms                      2.205953e+00
# bedrooms                       3.586353e+00
# beds                           5.687214e+00
# price                          1.037102e+03
# minimum_nights                 2.151893e+02
# maximum_nights                 2.115243e+03
# availability_30                3.449093e+01
# availability_60                7.910212e+01
# availability_365               5.300541e+02
# number_of_reviews              3.408647e+02
# number_of_reviews_ltm          7.513990e+01
# number_of_reviews_l30d         6.730990e+00
# review_scores_rating           5.674632e+00
# review_scores_accuracy         5.649061e+00
# review_scores_cleanliness      5.824730e+00
# review_scores_checkin          5.685785e+00
# review_scores_communication    5.719498e+00
# review_scores_location         5.624018e+00
# review_scores_value            5.748508e+00
# reviews_per_month              5.986162e+00
# dtype: float64

# %%
# Obtenemos los outliers y esos mismos los convertimos en nulos
df2 = cuantitativas[(y <= limSup) & (y >= limInf)]
df2
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      5.704900e+04                 1.0                  0.80
# 1      5.878000e+04                 1.0                  0.77
# 2      6.261300e+04                 1.0                  0.54
# 3      6.401400e+04                 0.5                  0.00
# 4      6.424500e+04                 1.0                  0.87
# ...             ...                 ...                   ...
# 11522  1.020000e+18                 1.0                  0.98
# 11523  1.020000e+18                 1.0                  0.98
# 11524  1.020000e+18                 1.0                  0.98
# 11525  1.020000e+18                 1.0                  0.98
# 11526  1.020000e+18                 1.0                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      3.0                        3.0           4.0
# 1                      4.0                        6.0           4.0
# 2                      1.0                        2.0           2.0
# 3                      1.0                        1.0           4.0
# 4                      1.0                        2.0           2.0
# ...                    ...                        ...           ...
# 11522                  9.0                        9.0           2.0
# 11523                  9.0                        9.0           2.0
# 11524                  9.0                        9.0           4.0
# 11525                  9.0                        9.0           2.0
# 11526                  9.0                        9.0           4.0
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            2.0       2.0   3.0  290.0  ...                   15.0
# 1            1.5       3.0   3.0  240.0  ...                    7.0
# 2            1.0       0.0   1.0  100.0  ...                    4.0
# 3            2.0       2.0   2.0  186.0  ...                    0.0
# 4            1.5       1.0   1.0   78.0  ...                   22.0
# ...          ...       ...   ...    ...  ...                    ...
# 11522        1.0       1.0   1.0  275.0  ...                   11.0
# 11523        1.0       1.0   1.0  361.0  ...                    6.0
# 11524        2.0       1.0   1.0  516.0  ...                    6.0
# 11525        1.0       1.0   1.0  384.0  ...                    3.0
# 11526        2.0       2.0   2.0  595.0  ...                   33.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.93                    4.95
# 1                         1.0                  4.84                    4.88
# 2                         0.0                  4.70                    4.68
# 3                         0.0                  4.75                    4.63
# 4                         3.0                  4.95                    4.95
# ...                       ...                   ...                     ...
# 11522                     2.0                  5.00                    5.00
# 11523                     0.0                  4.83                    5.00
# 11524                     1.0                  5.00                    5.00
# 11525                     0.0                  4.67                    4.67
# 11526                     4.0                  4.97                    4.97
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.90                   4.97
# 1                           4.79                   4.81
# 2                           4.65                   4.82
# 3                           4.50                   4.94
# 4                           4.92                   4.95
# ...                          ...                    ...
# 11522                       4.91                   4.82
# 11523                       5.00                   4.83
# 11524                       5.00                   5.00
# 11525                       5.00                   5.00
# 11526                       5.00                   4.94
#
#        review_scores_communication  review_scores_location  \
# 0                             4.94                    4.82
# 1                             4.91                    4.87
# 2                             4.82                    4.94
# 3                             4.63                    4.88
# 4                             4.92                    4.84
# ...                            ...                     ...
# 11522                         5.00                    5.00
# 11523                         5.00                    4.83
# 11524                         5.00                    4.83
# 11525                         5.00                    4.33
# 11526                         4.97                    4.85
#
#        review_scores_value  reviews_per_month
# 0                     4.76               0.80
# 1                     4.73               0.43
# 2                     4.47               0.20
# 3                     4.40               0.10
# 4                     4.77               0.73
# ...                    ...                ...
# 11522                 4.45               1.21
# 11523                 4.67               0.65
# 11524                 4.50               1.84
# 11525                 4.33               0.94
# 11526                 4.85               3.69
#
# [11527 rows x 26 columns]

# %%
# Corroboramos valores nulos (atípicos) del dataframe
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# id                               0
# host_response_rate             494
# host_acceptance_rate             0
# host_listings_count            306
# host_total_listings_count      307
# accommodates                   173
# bathrooms                      170
# bedrooms                       185
# beds                           277
# price                           38
# minimum_nights                  39
# maximum_nights                   3
# availability_30                  0
# availability_60                  0
# availability_365                 0
# number_of_reviews              237
# number_of_reviews_ltm          129
# number_of_reviews_l30d         143
# review_scores_rating           104
# review_scores_accuracy         119
# review_scores_cleanliness      203
# review_scores_checkin          256
# review_scores_communication    127
# review_scores_location         128
# review_scores_value            155
# reviews_per_month              119
# dtype: int64

# %%
# Reemplazamos valores atípicos (nulos) del dataframe con la media aritmética (mean)
data_clean = df2.copy()
data_clean = data_clean.fillna(round(df2.mean(),1))
data_clean
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      5.704900e+04                 1.0                  0.80
# 1      5.878000e+04                 1.0                  0.77
# 2      6.261300e+04                 1.0                  0.54
# 3      6.401400e+04                 0.5                  0.00
# 4      6.424500e+04                 1.0                  0.87
# ...             ...                 ...                   ...
# 11522  1.020000e+18                 1.0                  0.98
# 11523  1.020000e+18                 1.0                  0.98
# 11524  1.020000e+18                 1.0                  0.98
# 11525  1.020000e+18                 1.0                  0.98
# 11526  1.020000e+18                 1.0                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      3.0                        3.0           4.0
# 1                      4.0                        6.0           4.0
# 2                      1.0                        2.0           2.0
# 3                      1.0                        1.0           4.0
# 4                      1.0                        2.0           2.0
# ...                    ...                        ...           ...
# 11522                  9.0                        9.0           2.0
# 11523                  9.0                        9.0           2.0
# 11524                  9.0                        9.0           4.0
# 11525                  9.0                        9.0           2.0
# 11526                  9.0                        9.0           4.0
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            2.0       2.0   3.0  290.0  ...                   15.0
# 1            1.5       3.0   3.0  240.0  ...                    7.0
# 2            1.0       0.0   1.0  100.0  ...                    4.0
# 3            2.0       2.0   2.0  186.0  ...                    0.0
# 4            1.5       1.0   1.0   78.0  ...                   22.0
# ...          ...       ...   ...    ...  ...                    ...
# 11522        1.0       1.0   1.0  275.0  ...                   11.0
# 11523        1.0       1.0   1.0  361.0  ...                    6.0
# 11524        2.0       1.0   1.0  516.0  ...                    6.0
# 11525        1.0       1.0   1.0  384.0  ...                    3.0
# 11526        2.0       2.0   2.0  595.0  ...                   33.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.93                    4.95
# 1                         1.0                  4.84                    4.88
# 2                         0.0                  4.70                    4.68
# 3                         0.0                  4.75                    4.63
# 4                         3.0                  4.95                    4.95
# ...                       ...                   ...                     ...
# 11522                     2.0                  5.00                    5.00
# 11523                     0.0                  4.83                    5.00
# 11524                     1.0                  5.00                    5.00
# 11525                     0.0                  4.67                    4.67
# 11526                     4.0                  4.97                    4.97
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.90                   4.97
# 1                           4.79                   4.81
# 2                           4.65                   4.82
# 3                           4.50                   4.94
# 4                           4.92                   4.95
# ...                          ...                    ...
# 11522                       4.91                   4.82
# 11523                       5.00                   4.83
# 11524                       5.00                   5.00
# 11525                       5.00                   5.00
# 11526                       5.00                   4.94
#
#        review_scores_communication  review_scores_location  \
# 0                             4.94                    4.82
# 1                             4.91                    4.87
# 2                             4.82                    4.94
# 3                             4.63                    4.88
# 4                             4.92                    4.84
# ...                            ...                     ...
# 11522                         5.00                    5.00
# 11523                         5.00                    4.83
# 11524                         5.00                    4.83
# 11525                         5.00                    4.33
# 11526                         4.97                    4.85
#
#        review_scores_value  reviews_per_month
# 0                     4.76               0.80
# 1                     4.73               0.43
# 2                     4.47               0.20
# 3                     4.40               0.10
# 4                     4.77               0.73
# ...                    ...                ...
# 11522                 4.45               1.21
# 11523                 4.67               0.65
# 11524                 4.50               1.84
# 11525                 4.33               0.94
# 11526                 4.85               3.69
#
# [11527 rows x 26 columns]

# %%
# Corroboramos valores nulos
data_clean.isnull().sum()
# Out:
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %% [markdown]
# **Procedimiento "Ipercuantílico" para sustituir outliers en el dataframe**

# %%
y = cuantitativas

percentil25 = y.quantile(0.25) #Q1
percentil75 = y.quantile(0.75) #Q2
iqr = percentil75 - percentil25

limSupIQR = percentil75 + (1.5 * iqr)
limInfIQR = percentil25 - (1.5 * iqr)
print("Limites superior: ", limSupIQR)
print("Limite inferior: ", limInfIQR)
# Out:
# Limites superior:  id                             1.522500e+18
# host_response_rate             1.000000e+00
# host_acceptance_rate           1.450000e+00
# host_listings_count            8.500000e+00
# host_total_listings_count      1.100000e+01
# accommodates                   7.000000e+00
# bathrooms                      1.500000e+00
# bedrooms                       1.000000e+00
# beds                           3.500000e+00
# price                          3.325000e+02
# minimum_nights                 2.270000e+02
# maximum_nights                 2.674500e+03
# availability_30                2.750000e+01
# availability_60                8.250000e+01
# availability_365               6.500000e+02
# number_of_reviews              1.160000e+02
# number_of_reviews_ltm          2.750000e+01
# number_of_reviews_l30d         2.500000e+00
# review_scores_rating           5.320000e+00
# review_scores_accuracy         5.265000e+00
# review_scores_cleanliness      5.320000e+00
# review_scores_checkin          5.255000e+00
# review_scores_communication    5.300000e+00
# review_scores_location         5.255000e+00
# review_scores_value            5.365000e+00
# reviews_per_month              2.525000e+00
# dtype: float64
# Limite inferior:  id                            -9.135000e+17
# host_response_rate             1.000000e+00
# host_acceptance_rate           2.500000e-01
# host_listings_count           -3.500000e+00
# host_total_listings_count     -5.000000e+00
# accommodates                  -1.000000e+00
# bathrooms                      7.000000e-01
# bedrooms                       1.000000e+00
# beds                          -5.000000e-01
# price                         -8.750000e+01
# minimum_nights                -1.330000e+02
# maximum_nights                -1.457500e+03
# availability_30               -1.650000e+01
# availability_60               -4.950000e+01
# availability_365              -3.900000e+02
# number_of_reviews             -6.800000e+01
# number_of_reviews_ltm         -1.650000e+01
# number_of_reviews_l30d        -1.500000e+00
# review_scores_rating           4.360000e+00
# review_scores_accuracy         4.505000e+00
# review_scores_cleanliness      4.280000e+00
# review_scores_checkin          4.575000e+00
# review_scores_communication    4.500000e+00
# review_scores_location         4.415000e+00
# review_scores_value            4.125000e+00
# reviews_per_month             -1.275000e+00
# dtype: float64

# %%
# Obtenemos datos limpios del dataframe
df2_iqr = cuantitativas[(y <= limSupIQR) & (y >= limInfIQR)]
df2_iqr
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      5.704900e+04                 1.0                  0.80
# 1      5.878000e+04                 1.0                  0.77
# 2      6.261300e+04                 1.0                  0.54
# 3      6.401400e+04                 NaN                   NaN
# 4      6.424500e+04                 1.0                  0.87
# ...             ...                 ...                   ...
# 11522  1.020000e+18                 1.0                  0.98
# 11523  1.020000e+18                 1.0                  0.98
# 11524  1.020000e+18                 1.0                  0.98
# 11525  1.020000e+18                 1.0                  0.98
# 11526  1.020000e+18                 1.0                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      3.0                        3.0           4.0
# 1                      4.0                        6.0           4.0
# 2                      1.0                        2.0           2.0
# 3                      1.0                        1.0           4.0
# 4                      1.0                        2.0           2.0
# ...                    ...                        ...           ...
# 11522                  NaN                        9.0           2.0
# 11523                  NaN                        9.0           2.0
# 11524                  NaN                        9.0           4.0
# 11525                  NaN                        9.0           2.0
# 11526                  NaN                        9.0           4.0
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            NaN       NaN   3.0  290.0  ...                   15.0
# 1            1.5       NaN   3.0  240.0  ...                    7.0
# 2            1.0       NaN   1.0  100.0  ...                    4.0
# 3            NaN       NaN   2.0  186.0  ...                    0.0
# 4            1.5       1.0   1.0   78.0  ...                   22.0
# ...          ...       ...   ...    ...  ...                    ...
# 11522        1.0       1.0   1.0  275.0  ...                   11.0
# 11523        1.0       1.0   1.0    NaN  ...                    6.0
# 11524        NaN       1.0   1.0    NaN  ...                    6.0
# 11525        1.0       1.0   1.0    NaN  ...                    3.0
# 11526        NaN       NaN   2.0    NaN  ...                    NaN
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.93                    4.95
# 1                         1.0                  4.84                    4.88
# 2                         0.0                  4.70                    4.68
# 3                         0.0                  4.75                    4.63
# 4                         NaN                  4.95                    4.95
# ...                       ...                   ...                     ...
# 11522                     2.0                  5.00                    5.00
# 11523                     0.0                  4.83                    5.00
# 11524                     1.0                  5.00                    5.00
# 11525                     0.0                  4.67                    4.67
# 11526                     NaN                  4.97                    4.97
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.90                   4.97
# 1                           4.79                   4.81
# 2                           4.65                   4.82
# 3                           4.50                   4.94
# 4                           4.92                   4.95
# ...                          ...                    ...
# 11522                       4.91                   4.82
# 11523                       5.00                   4.83
# 11524                       5.00                   5.00
# 11525                       5.00                   5.00
# 11526                       5.00                   4.94
#
#        review_scores_communication  review_scores_location  \
# 0                             4.94                    4.82
# 1                             4.91                    4.87
# 2                             4.82                    4.94
# 3                             4.63                    4.88
# 4                             4.92                    4.84
# ...                            ...                     ...
# 11522                         5.00                    5.00
# 11523                         5.00                    4.83
# 11524                         5.00                    4.83
# 11525                         5.00                     NaN
# 11526                         4.97                    4.85
#
#        review_scores_value  reviews_per_month
# 0                     4.76               0.80
# 1                     4.73               0.43
# 2                     4.47               0.20
# 3                     4.40               0.10
# 4                     4.77               0.73
# ...                    ...                ...
# 11522                 4.45               1.21
# 11523                 4.67               0.65
# 11524                 4.50               1.84
# 11525                 4.33               0.94
# 11526                 4.85                NaN
#
# [11527 rows x 26 columns]

# %%
# Corroboramos valores nulos
df2_iqr.isnull().sum()
# Out:
# id                                0
# host_response_rate             2820
# host_acceptance_rate            981
# host_listings_count            1681
# host_total_listings_count      1629
# accommodates                    322
# bathrooms                       763
# bedrooms                       3334
# beds                            892
# price                           639
# minimum_nights                   39
# maximum_nights                    3
# availability_30                 763
# availability_60                   0
# availability_365                  0
# number_of_reviews              1407
# number_of_reviews_ltm          1497
# number_of_reviews_l30d         1176
# review_scores_rating            753
# review_scores_accuracy          919
# review_scores_cleanliness       939
# review_scores_checkin           878
# review_scores_communication     597
# review_scores_location          796
# review_scores_value             640
# reviews_per_month              1242
# dtype: int64

# %%
# Reemplazamos los valores atípicos (nulos) con mean()
df3_iqr = df2_iqr.copy()
df3_iqr = df3_iqr.fillna(round(df3_iqr.mean(),1))
# Out:
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
df3_iqr.isnull().sum()
# Out:
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
# Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
dataframe_limpio = pd.concat([cualitativas, df3_iqr], axis = 1)
dataframe_limpio
# Out:
#       last_scraped                                               name  \
# 0       18/09/2024                  130 sqm with a view on Mauer Park
# 1       18/09/2024                  light quiet beautiful 4 room flat
# 2       18/09/2024                Super Apartment in Berlin/Kreuzberg
# 3       18/09/2024  Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4       18/09/2024  Room w/ balcony and private bathroom in nice area
# ...            ...                                                ...
# 11522   18/09/2024                                          Studio 40
# 11523   18/09/2024                                     Garden Loft 80
# 11524   18/09/2024                           Extended Garden Loft 107
# 11525   18/09/2024                                    Garden Loft 115
# 11526   18/09/2024                           Extended Garden Loft 139
#
#                                              description  \
# 0      An apartment of 130 sqm right in the heart of ...
# 1      We offer our 4 room apartment in Prenzlauer Be...
# 2      Our fantastic typical Berlin-style apartment i...
# 3      I am renting out my spacious, bright rooftop a...
# 4      I¬¨¬•m offering a guest room with balcony in m...
# ...                                                  ...
# 11522  This modern flat is located in the new Carlott...
# 11523  This modern apartment is located in the new Ca...
# 11524  This modern flat is located in the new Carlott...
# 11525  This modern apartment is located in the new Ca...
# 11526  This modern flat is located in the new Carlott...
#
#                                    neighborhood_overview  \
# 0      Prenzlauer Berg is no doubt one of the most my...
# 1      Prenzlauer Berg is no doubt one of the most my...
# 2      Prenzlauer Berg is no doubt one of the most my...
# 3      Kastanienalle, Oderberger Strasse, Hackescher ...
# 4      The neighborhood "Prenzlauer Berg" is centrall...
# ...                                                  ...
# 11522  Charlottenburg in the western part of Berlin, ...
# 11523  Charlottenburg in the western part of Berlin, ...
# 11524  Charlottenburg in the western part of Berlin, ...
# 11525  Charlottenburg in the western part of Berlin, ...
# 11526  Charlottenburg in the western part of Berlin, ...
#
#                                              picture_url            host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...               Marine
# 1      https://a0.muscache.com/pictures/caa048ba-e297...                Katja
# 2      https://a0.muscache.com/pictures/176e2964-5ead...                Guidi
# 3      https://a0.muscache.com/pictures/1135114/9db3c...              Stephan
# 4      https://a0.muscache.com/pictures/miso/Hosting-...            Christian
# ...                                                  ...                  ...
# 11522  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11523  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11524  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11525  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
# 11526  https://a0.muscache.com/pictures/miso/Hosting-...  Carlotta Apartments
#
#        host_since                                         host_about  \
# 0      14/11/2009  I'm french but I have been living in Berlin si...
# 1      08/11/2010           Designer who likes discovering the world
# 2      08/09/2010  Hi , I am Elena and I am looking forward to ho...
# 3      08/12/2010  Ich mag sch‚àö‚àÇne Dinge und Design. Wenn es ...
# 4      07/12/2010  Christian from Berlin\n\nHi, I¬¨¬•m a 52 years...
# ...           ...                                                ...
# 11522  24/10/2023  "If you think you can do a thing or think you ...
# 11523  24/10/2023  "If you think you can do a thing or think you ...
# 11524  24/10/2023  "If you think you can do a thing or think you ...
# 11525  24/10/2023  "If you think you can do a thing or think you ...
# 11526  24/10/2023  "If you think you can do a thing or think you ...
#
#        host_response_time host_is_superhost  ... number_of_reviews_ltm  \
# 0          within an hour                 t  ...                  15.0
# 1      within a few hours                 t  ...                   7.0
# 2      within a few hours                 f  ...                   4.0
# 3            within a day                 f  ...                   0.0
# 4      within a few hours                 t  ...                  22.0
# ...                   ...               ...  ...                   ...
# 11522      within an hour                 t  ...                  11.0
# 11523      within an hour                 t  ...                   6.0
# 11524      within an hour                 t  ...                   6.0
# 11525      within an hour                 t  ...                   3.0
# 11526      within an hour                 t  ...                   3.7
#
#       number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 0                        0.0                 4.93                   4.95
# 1                        1.0                 4.84                   4.88
# 2                        0.0                 4.70                   4.68
# 3                        0.0                 4.75                   4.63
# 4                        0.3                 4.95                   4.95
# ...                      ...                  ...                    ...
# 11522                    2.0                 5.00                   5.00
# 11523                    0.0                 4.83                   5.00
# 11524                    1.0                 5.00                   5.00
# 11525                    0.0                 4.67                   4.67
# 11526                    0.3                 4.97                   4.97
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          4.90                  4.97
# 1                          4.79                  4.81
# 2                          4.65                  4.82
# 3                          4.50                  4.94
# 4                          4.92                  4.95
# ...                         ...                   ...
# 11522                      4.91                  4.82
# 11523                      5.00                  4.83
# 11524                      5.00                  5.00
# 11525                      5.00                  5.00
# 11526                      5.00                  4.94
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.94                   4.82                4.76
# 1                            4.91                   4.87                4.73
# 2                            4.82                   4.94                4.47
# 3                            4.63                   4.88                4.40
# 4                            4.92                   4.84                4.77
# ...                           ...                    ...                 ...
# 11522                        5.00                   5.00                4.45
# 11523                        5.00                   4.83                4.67
# 11524                        5.00                   4.83                4.50
# 11525                        5.00                   4.80                4.33
# 11526                        4.97                   4.85                4.85
#
#       reviews_per_month
# 0                  0.80
# 1                  0.43
# 2                  0.20
# 3                  0.10
# 4                  0.73
# ...                 ...
# 11522              1.21
# 11523              0.65
# 11524              1.84
# 11525              0.94
# 11526              0.50
#
# [11527 rows x 50 columns]

# %%
#Corroboramos valores nulos
dataframe_limpio.isnull().sum()
# Out:
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_is_superhost              0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# bathrooms_text                 0
# amenities                      0
# calendar_updated               0
# has_availability               0
# calendar_last_scraped          0
# last_review                    0
# license                        0
# instant_bookable               0
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
# Convertimos dataframe limpio a csv
dataframe_limpio.to_csv("Datos_limpios.csv")
